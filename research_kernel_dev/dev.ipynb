# %%
import torch
print('DEVCOUNT', torch.cuda.device_count())
[print('GPU',i,torch.cuda.get_device_name(i),round(torch.cuda.get_device_properties(i).total_memory/1e9,1),'GB') for i in range(torch.cuda.device_count())]
print('DEVPROBE DONE')
